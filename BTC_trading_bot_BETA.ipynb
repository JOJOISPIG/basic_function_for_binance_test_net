# %%
#!/usr/bin/env python
import logging
import time
import os
from binance.um_futures import UMFutures
from binance.error import ClientError
from dotenv import load_dotenv
import pandas as pd

logging.basicConfig(level=logging.INFO)

# Read API
load_dotenv(dotenv_path="API.env")
# Out:
# True

# %%
api_key = os.getenv("API_KEY")
api_secret = os.getenv("API_SECRET")
if not api_key or not api_secret:
    logging.error("API Key and Secret must be set in the .env file")
    exit(1)

# %%
# build Futures Client
client = UMFutures(key=api_key, secret=api_secret, base_url="https://testnet.binancefuture.com")

# Parameter setting
symbol = "BTCUSDT"
quantity_ratio = 0.5  # Balance ratio
short_ma_period = 20
long_ma_period = 60
take_profit_ratio = 0.3   #  TP：0.3%
stop_loss_ratio = 0.3     #  SL：-0.3%

def get_balance():
    account_info = client.balance()
    for asset in account_info:
        if asset["asset"] == "USDT":
            return float(asset["balance"])
    return 0.0

def get_latest_price(symbol):
    price_info = client.ticker_price(symbol=symbol)
    return float(price_info["price"])

def get_ma_signal(symbol):
    kline = client.klines(symbol=symbol, interval="1m", limit=long_ma_period+1)
    df = pd.DataFrame(kline, columns=["timestamp","open","high","low","close","volume",
                                      "close_time","quote_asset_volume","number_of_trades",
                                      "taker_buy_base_asset_volume","taker_buy_quote_asset_volume","ignore"])
    df["close"] = df["close"].astype(float)
    df["short_ma"] = df["close"].rolling(window=short_ma_period).mean()
    df["long_ma"] = df["close"].rolling(window=long_ma_period).mean()

    if df["short_ma"].iloc[-2] < df["long_ma"].iloc[-2] and df["short_ma"].iloc[-1] > df["long_ma"].iloc[-1]:
        return "BUY"  # long
    elif df["short_ma"].iloc[-2] > df["long_ma"].iloc[-2] and df["short_ma"].iloc[-1] < df["long_ma"].iloc[-1]:
        return "SELL"  # short
    else:
        return "HOLD"

# %%
def place_order(side, quantity, entry_price):
    position_side = "LONG" if side == "BUY" else "SHORT"
    close_side = "SELL" if side == "BUY" else "BUY"

    # Main order
    order = client.new_order(
        symbol=symbol,
        side=side,
        type="MARKET",
        quantity=quantity,
        positionSide=position_side,
    )
    logging.info(f"ORDER PLACED: {order}")

    # Calulate TP/SL
    take_profit_price = entry_price * take_profit_ratio if side == "BUY" else entry_price * stop_loss_ratio
    stop_loss_price = entry_price * stop_loss_ratio if side == "BUY" else entry_price * take_profit_ratio

    # Setting TP
    client.new_order(
        symbol=symbol,
        side=close_side,
        type="TAKE_PROFIT_MARKET",
        stopPrice=round(take_profit_price, 2),
        closePosition=True,
        positionSide=position_side,
        workingType="CONTRACT_PRICE",
    )

    # Setting SL
    client.new_order(
        symbol=symbol,
        side=close_side,
        type="STOP_MARKET",
        stopPrice=round(stop_loss_price, 2),
        closePosition=True,
        positionSide=position_side,
        workingType="CONTRACT_PRICE",
    )

    logging.info(f"TP: {round(take_profit_price, 2)}, SL: {round(stop_loss_price, 2)}")

# %%
def calculate_profit(symbol):
    positions = client.position_information(symbol=symbol)
    for pos in positions:
        if float(pos["positionAmt"]) != 0:
            entry_price = float(pos["entryPrice"])
            mark_price = float(pos["markPrice"])
            side = "LONG" if float(pos["positionAmt"]) > 0 else "SHORT"
            quantity = abs(float(pos["positionAmt"]))
            pnl = float(pos["unRealizedProfit"])
            logging.info(f"SIDE: {side} ENTRY_PRICE: {entry_price} MARK_PRICE: {mark_price} PNL: {pnl}")
            return pnl, mark_price
    return 0, 0

# %%
def main():
    while True:
        try:
            signal = get_ma_signal(symbol)
            logging.info(f"SIGNAL: {signal}")

            if signal in ["BUY", "SELL"]:
                usdt_balance = get_balance()
                latest_price = get_latest_price(symbol)
                quantity = round((usdt_balance * quantity_ratio) / latest_price, 3)

                # Order at Mark price
                place_order(signal, quantity, latest_price)

                
                time.sleep(10)

                # Calculate PNL
                pnl, now_price = calculate_profit(symbol)
                final_balance = get_balance()

                logging.info(f"LATEST_PRICE: {latest_price} | NOW_PRICE: {now_price} | PNL: {pnl} | FINAL_BLANCE: {final_balance} USDT")

                break  
            else:
                logging.info("waiting for next signal...")
            time.sleep(10)

        except ClientError as e:
            logging.error(f"API Error: {e}")
            time.sleep(5)
        except Exception as ex:
            logging.error(f"Unexpected Error: {ex}")
            time.sleep(5)

if __name__ == "__main__":
    main()
# Out:
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: SELL
# INFO:root:開倉單送出: {'orderId': 4375464251, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': '5erQVkCgBShQg4lgDEEk2U', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'SHORT', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745831570029}
# INFO:root:止盈價: 93701.52, 止損價: 95594.48
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: SELL
# INFO:root:開倉單送出: {'orderId': 4375464454, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'RdiVowKeyoc5Mg6EH0EwUG', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'SHORT', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745831585416}
# INFO:root:止盈價: 93700.23, 止損價: 95593.17
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: SELL
# INFO:root:開倉單送出: {'orderId': 4375464699, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'tEb0i1IXoXCwYoekvTB1Xk', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'SHORT', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745831600814}
# INFO:root:止盈價: 93678.65, 止損價: 95571.15
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: SELL
# INFO:root:開倉單送出: {'orderId': 4375465028, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'vGVqVR8V0tuSe3nEt7ECVk', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'SHORT', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745831616341}
# INFO:root:止盈價: 93683.7, 止損價: 95576.3
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: SELL
# INFO:root:開倉單送出: {'orderId': 4375465335, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'oVgZc6frh6f32nHoFSj10w', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'SHORT', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745831631736}
# INFO:root:止盈價: 93683.7, 止損價: 95576.3
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: BUY
# INFO:root:開倉單送出: {'orderId': 4375487046, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'tswYcQzrHZUqsxrvhRwLvO', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'LONG', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745832414979}
# INFO:root:止盈價: 95631.45, 止損價: 93737.75
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: BUY
# INFO:root:開倉單送出: {'orderId': 4375487558, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'tuWuGCUuBnGk9IWxTHLIB1', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'LONG', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745832430572}
# INFO:root:止盈價: 95631.45, 止損價: 93737.75
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: BUY
# INFO:root:開倉單送出: {'orderId': 4375488257, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'aEQh42VmWgGerfkmHNKu1s', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'LONG', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745832446107}
# INFO:root:止盈價: 95631.65, 止損價: 93737.95
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: BUY
# INFO:root:開倉單送出: {'orderId': 4375488651, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': '8yaFeIgNdyfHuDkYC8wydZ', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'LONG', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745832461638}
# INFO:root:止盈價: 95633.26, 止損價: 93739.54
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: BUY
# INFO:root:開倉單送出: {'orderId': 4375566156, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': '5K98iIDUM3WedG0gjpK5CZ', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'LONG', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745835069381}
# INFO:root:止盈價: 95683.36, 止損價: 93788.64
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: BUY
# INFO:root:開倉單送出: {'orderId': 4375566628, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'RDilldQCOazFP2tKDQ6nOi', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'LONG', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745835084776}
# INFO:root:止盈價: 95682.65, 止損價: 93787.95
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: BUY
# INFO:root:開倉單送出: {'orderId': 4375567373, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'DxWNWmLN02ET688PBnBS9j', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'LONG', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745835100302}
# INFO:root:止盈價: 95646.9, 止損價: 93752.9
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: BUY
# INFO:root:開倉單送出: {'orderId': 4375567852, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': '6p2ptvBkWf8u4CuFbeQWtG', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'LONG', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745835115949}
# INFO:root:止盈價: 95645.49, 止損價: 93751.51
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: BUY
# INFO:root:開倉單送出: {'orderId': 4375568402, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'bo4GAMjUemOFgk1ahRPurV', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'LONG', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745835131535}
# INFO:root:止盈價: 95647.3, 止損價: 93753.3
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: SELL
# INFO:root:開倉單送出: {'orderId': 4375573402, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'SWtpZSSLHQydiF1crO9b3x', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'SHORT', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745835318674}
# INFO:root:止盈價: 93700.93, 止損價: 95593.87
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: SELL
# INFO:root:開倉單送出: {'orderId': 4375573764, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'p4IwRKwdb10ae5ASKvAUUj', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'SHORT', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745835334211}
# INFO:root:止盈價: 93679.44, 止損價: 95571.96
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: SELL
# INFO:root:開倉單送出: {'orderId': 4375574193, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'mRaBCYHPa6cIakULbmhno1', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'SHORT', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745835349793}
# INFO:root:止盈價: 93705.38, 止損價: 95598.42
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: SELL
# INFO:root:開倉單送出: {'orderId': 4375574577, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'YVUWNoLWYcuAWIREoXkByP', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'SHORT', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745835365175}
# INFO:root:止盈價: 93692.02, 止損價: 95584.78
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: SELL
# INFO:root:開倉單送出: {'orderId': 4375574999, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'VMgmz8EH17i4DiU1MHoDZO', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'SELL', 'positionSide': 'SHORT', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745835380761}
# INFO:root:止盈價: 93692.02, 止損價: 95584.78
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: BUY
# INFO:root:開倉單送出: {'orderId': 4375614901, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'Figm3jRRoJC9A1u0Az8PQ8', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'LONG', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745836285222}
# INFO:root:止盈價: 95558.42, 止損價: 93666.18
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: BUY
# INFO:root:開倉單送出: {'orderId': 4375615758, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'iqg6KYcsttbiKBEWbtXGGq', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'LONG', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745836300901}
# INFO:root:止盈價: 95579.94, 止損價: 93687.26
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: BUY
# INFO:root:開倉單送出: {'orderId': 4375616246, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'J1gduuo114NDa8Bw57JpT3', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'LONG', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745836316414}
# INFO:root:止盈價: 95581.05, 止損價: 93688.35
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: BUY
# INFO:root:開倉單送出: {'orderId': 4375616914, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'nVjIaUGvpBdcEx0JbnOYag', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'LONG', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745836331881}
# INFO:root:止盈價: 95619.02, 止損價: 93725.58
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: BUY
# INFO:root:開倉單送出: {'orderId': 4375617787, 'symbol': 'BTCUSDT', 'status': 'NEW', 'clientOrderId': 'pbHaWz4ChOFERPAY0nwShA', 'price': '0.00', 'avgPrice': '0.00', 'origQty': '0.005', 'executedQty': '0.000', 'cumQty': '0.000', 'cumQuote': '0.00000', 'timeInForce': 'GTC', 'type': 'MARKET', 'reduceOnly': False, 'closePosition': False, 'side': 'BUY', 'positionSide': 'LONG', 'stopPrice': '0.00', 'workingType': 'CONTRACT_PRICE', 'priceProtect': False, 'origType': 'MARKET', 'priceMatch': 'NONE', 'selfTradePreventionMode': 'EXPIRE_MAKER', 'goodTillDate': 0, 'updateTime': 1745836347450}
# INFO:root:止盈價: 95620.24, 止損價: 93726.76
# ERROR:root:Unexpected Error: 'UMFutures' object has no attribute 'position_information'
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# INFO:root:目前訊號: HOLD
# INFO:root:等待下一個交叉訊號...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 37
#      34             time.sleep(5)
#      36 if __name__ == "__main__":
# ---> 37     main()
#
# Cell In[29], line 27, in main()
#      25     else:
#      26         logging.info("等待下一個交叉訊號...")
# ---> 27     time.sleep(10)
#      29 except ClientError as e:
#      30     logging.error(f"API Error: {e}")
#
# KeyboardInterrupt:
